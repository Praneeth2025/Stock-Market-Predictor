# %%
import pandas as pd
import numpy as np

# %%
import importlib
import seaborn as sns

# %%
import main
# Out:
# c:\Users\vamsi\OneDrive\Desktop\Documents\studies\complete stock market predictor\venv\Lib\site-packages\pandas_ta\__init__.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound
# HELLO

# %%
importlib.reload(main)
# Out:
# HELLO
# 106
# <module 'main' from 'c:\\Users\\vamsi\\OneDrive\\Desktop\\Documents\\studies\\complete stock market predictor\\Stock-Market-Predictor\\project_root\\notebooks\\main.py'>

# %%
x=main.x
x
# Out:
#            ATR  Supertrend_Direction        RSI       MACD  Day of the week  \
# 33    8.850071                     1  70.917361  13.284103                1
# 34    8.821071                     1  73.804592  13.583891                1
# 35    8.390571                     1  75.122215  13.912535                1
# 36    8.957929                     1  64.948183  13.292646                1
# 37    9.386429                     1  62.153490  12.433888                1
# ...        ...                   ...        ...        ...              ...
# 5842  2.158786                    -1  36.676534  -0.891610                4
# 5843  2.016929                    -1  43.561901  -0.908368                4
# 5844  1.856786                    -1  43.171129  -0.921198                4
# 5845  1.927286                    -1  48.112163  -0.821675                4
# 5846  1.927357                    -1  45.808677  -0.787545                4
#
#       Is Weekend  Month  hour  high_liquidity
# 33         False     22     5               0
# 34         False     22     5               0
# 35         False     22     6               0
# 36         False     22     6               0
# 37         False     22     6               0
# ...          ...    ...   ...             ...
# 5842        True     18    19               0
# 5843        True     18    20               0
# 5844        True     18    20               0
# 5845        True     18    20               0
# 5846        True     18    20               0
#
# [5718 rows x 9 columns]

# %%
x_tr=x.iloc[:,4:]

# %%
x_tr
# Out:
#       tick_volume       ATR  Supertrend_Direction        RSI       MACD  \
# 33           6292  2.287479                     1  70.917361  13.284103
# 34           5828  2.284530                     1  73.804592  13.583891
# 35           6223  2.239706                     1  75.122215  13.912535
# 36           8607  2.298369                     1  64.948183  13.292646
# 37           9130  2.340500                     1  62.153490  12.433888
# ...           ...       ...                   ...        ...        ...
# 5842         1276  1.150188                    -1  36.676534  -0.891610
# 5843          894  1.104239                    -1  43.561901  -0.908368
# 5844          683  1.049697                    -1  43.171129  -0.921198
# 5845          715  1.074076                    -1  48.112163  -0.821675
# 5846         1171  1.074100                    -1  45.808677  -0.787545
#
#       MACD_signal  MACD_diff  Day of the week  Is Weekend  Month
# 33      14.225845  -0.941742                1           0     22
# 34      14.097454  -0.513563                1           0     22
# 35      14.060470  -0.147935                1           0     22
# 36      13.906905  -0.614259                1           0     22
# 37      13.612302  -1.178414                1           0     22
# ...           ...        ...              ...         ...    ...
# 5842    -0.389349  -0.502261                4           1     18
# 5843    -0.493153  -0.415216                4           1     18
# 5844    -0.578762  -0.342436                4           1     18
# 5845    -0.627344  -0.194330                4           1     18
# 5846    -0.659384  -0.128160                4           1     18
#
# [5814 rows x 10 columns]

# %%
sns.histplot(data=main.data['ATR'],kde=True)
# Out:
# <Axes: xlabel='ATR', ylabel='Count'>

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler

# X = your dataset
X_scaled = StandardScaler().fit_transform(x)

pca = PCA()
pca.fit(main.x_standardized)

explained_var = pca.explained_variance_ratio_
cumulative_var = np.cumsum(explained_var)

plt.plot(range(1, len(cumulative_var)+1), cumulative_var, marker='o')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('PCA Elbow Method')
plt.grid(True)
plt.show()

# %%
data=main.data

# %%
x=data.drop(['result'],axis=1)

# %%
x.drop(['time'],axis=1,inplace=True)
x
# Out:
#           open      high       low     close  tick_volume       ATR  \
# 33    3480.695  3488.334  3473.547  3488.181         6292  2.287479
# 34    3488.206  3495.669  3487.753  3494.471         5828  2.284530
# 35    3494.424  3498.510  3489.040  3497.587         6223  2.239706
# 36    3497.543  3500.113  3482.480  3488.576         8607  2.298369
# 37    3488.445  3488.456  3476.803  3485.798         9130  2.340500
# ...        ...       ...       ...       ...          ...       ...
# 5842  3349.397  3349.820  3347.748  3348.396         1276  1.150188
# 5843  3348.359  3350.401  3347.884  3350.026          894  1.104239
# 5844  3350.019  3350.655  3349.391  3349.900          683  1.049697
# 5845  3349.969  3351.625  3349.078  3351.142          715  1.074076
# 5846  3351.170  3352.178  3349.776  3350.475         1171  1.074100
#
#       Supertrend_Direction        RSI       MACD  MACD_signal  MACD_diff  \
# 33                       1  70.917361  13.284103    14.225845  -0.941742
# 34                       1  73.804592  13.583891    14.097454  -0.513563
# 35                       1  75.122215  13.912535    14.060470  -0.147935
# 36                       1  64.948183  13.292646    13.906905  -0.614259
# 37                       1  62.153490  12.433888    13.612302  -1.178414
# ...                    ...        ...        ...          ...        ...
# 5842                    -1  36.676534  -0.891610    -0.389349  -0.502261
# 5843                    -1  43.561901  -0.908368    -0.493153  -0.415216
# 5844                    -1  43.171129  -0.921198    -0.578762  -0.342436
# 5845                    -1  48.112163  -0.821675    -0.627344  -0.194330
# 5846                    -1  45.808677  -0.787545    -0.659384  -0.128160
#
#       Day of the week  Is Weekend  Month
# 33                  1       False     22
# 34                  1       False     22
# 35                  1       False     22
# 36                  1       False     22
# 37                  1       False     22
# ...               ...         ...    ...
# 5842                4        True     18
# 5843                4        True     18
# 5844                4        True     18
# 5845                4        True     18
# 5846                4        True     18
#
# [5814 rows x 14 columns]

# %%
x['Is Weekend'] = x.select_dtypes(include='bool').astype(int)

# %%
sns.boxplot(data['ATR'])
# Out:
# <Axes: ylabel='ATR'>
